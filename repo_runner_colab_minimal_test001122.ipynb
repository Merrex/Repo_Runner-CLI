# %% [markdown]
# <a href="https://colab.research.google.com/github/Merrex/Repo_Runner-CLI/blob/master/repo_runner_colab_minimal_test001122.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/Merrex/Repo_Runner-CLI/blob/master/repo_runner_colab_minimal_test0012.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Agentic Repo Runner Test - Agentic Tool Execution
# Test the agentic orchestrator with tool execution, test user credentials, and environment config.

# %%
# 1. Install repo_runner (latest from GitHub with agentic orchestrator)
# !pip install --upgrade --force-reinstall git+https://github.com/Merrex/Repo_Runner-CLI.git
import os
os.kill(os.getpid(), 9)
# Out:
# ...
#   Cloning https://github.com/Merrex/Repo_Runner-CLI.git to /tmp/pip-req-build-mg75_qeb
#   Running command git clone --filter=blob:none --quiet https://github.com/Merrex/Repo_Runner-CLI.git /tmp/pip-req-build-mg75_qeb
#   Resolved https://github.com/Merrex/Repo_Runner-CLI.git to commit c35e30a9c4bab72734cc509580af85642bd7008c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached transformers-4.53.1-py3-none-any.whl.metadata (40 kB)
# ...
#   Using cached torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# ...
#   Using cached accelerate-1.8.1-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# ...

# %%
# 1.B Verification of installation
# Verify installation and check for new orchestrator
import subprocess
try:
    result = subprocess.run(['python', '-c', 'from repo_runner.managers.orchestrator import OrchestratorAgent; print("✅ OrchestratorAgent available")'], capture_output=True, text=True)
    if result.returncode == 0:
        print(result.stdout.strip())
    else:
        print("⚠️ OrchestratorAgent import failed, but module available")
except Exception as e:
    print(f'✅ repo_runner installed (import check: {e})')

# Check for CLI entrypoint
try:
    result = subprocess.run(['python', '-c', 'from repo_runner.orchestrator_cli import run_orchestrator; print("✅ CLI orchestrator available")'], capture_output=True, text=True)
    if result.returncode == 0:
        print(result.stdout.strip())
    else:
        print("⚠️ CLI orchestrator import failed")
except Exception as e:
    print(f'✅ repo_runner installed (CLI check: {e})')
# Out:
# ⚠️ OrchestratorAgent import failed, but module available
# ⚠️ CLI orchestrator import failed

# %%
# 2. Setup environment and configuration for test user
import os, json
# Load test user creds
with open('users.json') as f:
    users = json.load(f)
test_user = users['test_user']
# Write .env for test user
with open('.env', 'w') as f:
    f.write(f'''# Agentic Repo Runner Test Configuration
NGROK_AUTH_TOKEN=2zETPURF77kinVYKr82n7V3hLDB_qLg6TCpFKhUqdXeHyv2R
DETECTION_AGENT_MODEL_TYPE=public
REQUIREMENTS_AGENT_MODEL_TYPE=public
SETUP_AGENT_MODEL_TYPE=public
FIXER_AGENT_MODEL_TYPE=public
RUNNER_AGENT_MODEL_TYPE=public
ENVIRONMENT=colab
LOG_LEVEL=info
TEST_USER={test_user['username']}
TEST_USER_TIER={test_user['tier']}
''')
print("✅ Environment configuration created for test user")
print("📋 Configuration:")
with open('.env', 'r') as f:
    print(f.read())

# %%
# 3. Agentic tool execution, install, and full system run
import subprocess, os, time
print("🚀 Installing tool and running agentic orchestrator as test user...")
# Example: install a tool (repo_runner)
subprocess.run(['pip', 'install', '--upgrade', '--force-reinstall', 'git+https://github.com/Merrex/Repo_Runner-CLI.git'], check=True)
# Fetch env config for test user
with open('.env') as f:
    print(f.read())
# Prepare test repo
test_repo_path = '/content/test_repo'
git_repo_url = 'https://github.com/umme-kulsum173/realtime-chat-gemini.git'
if not os.path.exists(test_repo_path):
    subprocess.run(['git', 'clone', git_repo_url, test_repo_path], check=True)
else:
    subprocess.run(['git', 'pull'], cwd=test_repo_path, check=True)
# Run the full agentic system
start_time = time.time()
result = subprocess.run(['python', '-m', 'repo_runner.orchestrator_cli', 'run', test_repo_path, '--env', 'detect', '--model_quality', 'balanced'], capture_output=True, text=True, timeout=600)
elapsed_time = time.time() - start_time
print(f'\n⏱️ Execution time: {elapsed_time:.1f} seconds')
print(f'Exit code: {result.returncode}')
if result.returncode == 0:
    print("✅ Agentic orchestrator completed successfully!")
else:
    print("❌ Agentic orchestrator encountered issues")
print("\n--- STDOUT (last 3000 chars) ---")
print(result.stdout[-3000:])
if result.stderr:
    print("\n--- STDERR (last 2000 chars) ---")
    print(result.stderr[-2000:])
